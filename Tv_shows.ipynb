# %% [markdown]
# <a href="https://colab.research.google.com/github/Avazbek-CNU/TV-shows-assosiation-rule/blob/main/Tv_shows.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Apriori

# %% [markdown]
# Context
#
# Recommender system can always be built with context-based filtering or collaborative filtering. But with the help of this data, it can built using association rule learning/ Apriori Algorithm
#
# Content
#
# This dataset contains details of more than 9000 viewers watching TV shows. Each rows represent the TV shows they have watched together.
#
# Inspiration
#
# The dataset was heavily inspired from the famous groceries dataset which is used to learn association rule learning.

# %% [markdown]
# ## Importing the libraries

# %%
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5956 sha256=f83f3aa54ed531629f293b00ee98c959c08c3af1c20f827617bd0fe1e6263e1d
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Data Preprocessing

# %%
df = pd.read_csv('TV Shows.csv', header = None)

# %%
df
# Out:
#                  0              1                   2                 3   \
# 0         Cobra Kai          Lupin          12 Monkeys          Sherlock
# 1              Lost      Jack Ryan           The Flash   Game of thrones
# 2     Sex Education      Dr. House             Kingdom  The Walking Dead
# 3             Ozark  Sex Education         Constantine          Preacher
# 4            Naruto            NaN                 NaN               NaN
# ...             ...            ...                 ...               ...
# 9685      One Piece  The Blacklist  Two and a half men             Lupin
# 9686      One Piece      Mr. Robot          Succession             Ozark
# 9687      Daredevil       Atypical               Heros               NaN
# 9688       Absentia   The Newsroom        The Alienist               NaN
# 9689       Atypical            NaN                 NaN               NaN
#
#                   4                      5                    6       7   \
# ...

# %%
transactions = []
for i in range(0, 9690):
  transactions.append([str(df.values[i,j]) for j in range(0, 32)])

# %% [markdown]
# ## Training the Apriori model on the dataset

# %%
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)

# %% [markdown]
# ## Visualising the results

# %% [markdown]
# ### Displaying the first results coming directly from the output of the apriori function

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'Game of thrones', '12 Monkeys'}), support=0.0038183694530443757, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Game of thrones'}), items_add=frozenset({'12 Monkeys'}), confidence=0.22023809523809523, lift=3.757230885311871)]),
#  RelationRecord(items=frozenset({'Alice in Borderland', 'Daredevil'}), support=0.0071207430340557275, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alice in Borderland'}), items_add=frozenset({'Daredevil'}), confidence=0.2875, lift=3.061401098901099)]),
#  RelationRecord(items=frozenset({'The Wire', 'Arrow'}), support=0.005779153766769866, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Arrow'}), items_add=frozenset({'The Wire'}), confidence=0.22134387351778656, lift=3.367067714893802)]),
# ...

# %% [markdown]
# ### Putting the results well organised into a Pandas DataFrame

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %% [markdown]
# ### Displaying the results non sorted

# %%
resultsinDataFrame
# Out:
#          Left Hand Side Right Hand Side   Support  Confidence       Lift
# 0       Game of thrones      12 Monkeys  0.003818    0.220238   3.757231
# 1   Alice in Borderland       Daredevil  0.007121    0.287500   3.061401
# 2                 Arrow        The Wire  0.005779    0.221344   3.367068
# 3          Breaking Bad        The Wire  0.004231    0.253086   3.849933
# 4               The 100            Dark  0.004644    0.416667   4.673032
# 5       Game of thrones      Family Guy  0.004025    0.232143   3.245980
# 6              Punisher      Family Guy  0.004644    0.260116   3.637114
# 7        Rick And Morty      Family Guy  0.009185    0.276398   3.864779
# 8                Fringe            Lost  0.003096    0.379747  11.392405
# 9       Game of thrones         Vikings  0.004850    0.279762   8.290192
# 10   Person of Interest       Mr. Robot  0.006914    0.429487   3.926161
# 11   Queen of the South       Mr. Robot  0.017337    0.329412   3.011321

# %% [markdown]
# ### Displaying the results sorted by descending lifts

# %%
resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
# Out:
#         Left Hand Side Right Hand Side   Support  Confidence       Lift
# 8               Fringe            Lost  0.003096    0.379747  11.392405
# 9      Game of thrones         Vikings  0.004850    0.279762   8.290192
# 4              The 100            Dark  0.004644    0.416667   4.673032
# 10  Person of Interest       Mr. Robot  0.006914    0.429487   3.926161
# 7       Rick And Morty      Family Guy  0.009185    0.276398   3.864779
# 3         Breaking Bad        The Wire  0.004231    0.253086   3.849933
# 0      Game of thrones      12 Monkeys  0.003818    0.220238   3.757231
# 6             Punisher      Family Guy  0.004644    0.260116   3.637114
# 2                Arrow        The Wire  0.005779    0.221344   3.367068
# 5      Game of thrones      Family Guy  0.004025    0.232143   3.245980
